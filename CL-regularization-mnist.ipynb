# %%
# %load_ext autoreload
# %autoreload 2

import scod
import torch
import torch.nn as nn
import numpy as np
from tqdm import trange
import datetime
import random
import pickle


from torchvision import transforms
from torchvision.datasets import MNIST, FashionMNIST, KMNIST, EMNIST
from torch.utils.data import Subset
from torch.utils.data import DataLoader

import seaborn as sns
from matplotlib import pyplot as plt

from scripts.train_functions import create_dataloaders, main, set_up_model, load_ckp
from scripts.benchmark_functions import alg_flags, scod_flagger, ds_scod_flagger, create_scod_model, create_benchmark_seq_batches, get_Lt_J
from scripts.utils import eval_scod, init_scod

# %% [markdown]
# 1. Take a mixed batch (x% fashion, y% kmnist, z% test)\
# Flag OOD f% using scod k-highest/ds-scod
#
# 2. Continual training: \
#     a. Baseline method: mix new with old training\
#     b. Our method: use EWC to prevent forgetting\
#     Train for N epochs on mixture
#
# 3. Plot loss evolution on \
#     a. Mixture\
#     b. Just validation set (in distribution)\
#     c. FashionMNIST (OOD 1)\
#     d. KMNIST (OOD 2)

# %%
root="~/data/"
batch_size = 100
dataset_name = "mnist"

# %%
dataloaders, dataset_sizes = create_dataloaders(root, batch_size, dataset_name=dataset_name)

print(dataloaders)
# Out:
# {'mnist_train': <torch.utils.data.dataloader.DataLoader object at 0x7fa0657c7e50>, 'mnist_test': <torch.utils.data.dataloader.DataLoader object at 0x7fa033a8d150>, 'fashion': <torch.utils.data.dataloader.DataLoader object at 0x7fa0657c7ed0>, 'kmnist': <torch.utils.data.dataloader.DataLoader object at 0x7fa0657c7990>, 'emnist': <torch.utils.data.dataloader.DataLoader object at 0x7fa0657c7f90>}

# %% [markdown]
# # Add SCOD wrapper

# %%
load_model_path = "./best_model/mnist/best_model.pt"

unc_model = create_scod_model(load_model_path, dataset_name, batch_size)
# Out:
# Weight space dimension: 4.443e+04
# computing basis
# using T = 304
#   0%|          | 0/480 [00:00<?, ?it/s]

# %% [markdown]
# # Create mixture dataset using flagged inputs

# %%
ood_ratio = 0.50
mix_train_ratio = 0.01
num_batches = 5

ood_num = int(batch_size*ood_ratio)
mix_train_num = int(batch_size*mix_train_ratio)

# batch_compositions = [  {'mnist_test':batch_size - ood_num,'fashion':ood_num}]*num_batches
batch_compositions = [  {'mnist_test':batch_size - ood_num,'kmnist':ood_num}]*num_batches
train_batch_compositions = [{'mnist_train':mix_train_num}]*num_batches

flag_limit = ood_num
# algs_to_test = [lambda x: scod_flagger(x, unc_model, flag_limit=flag_limit, debug = False, dist_layer = scod.distributions.CategoricalLogitLayer()), 
#                 lambda x: ds_scod_flagger(x, unc_model, flag_limit=flag_limit, dist_layer = scod.distributions.CategoricalLogitLayer())]
algs_to_test = [lambda x: scod_flagger(x, unc_model, flag_limit=flag_limit, debug = False, dist_layer = scod.distributions.CategoricalLogitLayer())]
algs_names = ['scod_flagged']

flagged_inputs, flagged_labels, flagged_fnames, flags = alg_flags(algs_to_test, dataset_name, batch_size, num_batches, batch_compositions)
train_inputs, train_labels, train_fnames = create_benchmark_seq_batches(dataset_name, mix_train_num, num_batches, train_batch_compositions)
for k in range(len(algs_to_test)):
    for i in range(num_batches):
        flagged_subset = [(ts, lbl) for (ts,lbl,flg) in zip(flagged_inputs[i], flagged_labels[i], flags[i][k]) if flg]
        train_subset = [(ts, lbl) for (ts,lbl) in zip(train_inputs[i], train_labels[i])]
        refine_subset = flagged_subset + train_subset
        random.shuffle(refine_subset)

        mix_name = "mixture_"+str(batch_compositions[i])+'_'+algs_names[k]+'_'+str(len(flagged_subset))+'_train_'+str(len(train_subset))+"_batch_"+str(i)
        
        dataloaders[mix_name] = DataLoader(refine_subset, batch_size=batch_size, shuffle=True, num_workers=8)
        dataset_sizes[mix_name]  = len(refine_subset)
        print("Added ", mix_name, " to list of dataloaders.")
# Out:
# Test seq  0  algorithm  0  flagged:  [False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, False, True, True, False, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True]
# Test seq  1  algorithm  0  flagged:  [False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, False, True, True, True, True]
# Test seq  2  algorithm  0  flagged:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, True, True, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, True, True, True, False, True, True, True, True, False, True, True, True, True, False, True, True, True, True, False, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# Test seq  3  algorithm  0  flagged:  [False, False, False, False, True, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, True, True, True, True, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, False, False, True, True, True, True, True, True, True, True, True, True, True]
# Test seq  4  algorithm  0  flagged:  [True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, True, False, True, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, False, True, False, True, True, True, False, True, True, False, True]
# Added  mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0  to list of dataloaders.
# Added  mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1  to list of dataloaders.
# Added  mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2  to list of dataloaders.
# Added  mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3  to list of dataloaders.
# Added  mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4  to list of dataloaders.

# %% [markdown]
# # Resume training

# %%
# Resume training on train set
# phases = [('train','mnist_train'), ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

# Resume training on mixture
# phases = [('train',"mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_100"), 
#             ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]
# phases = [('train',"mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_1"), 
#             ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]
# phases = [('train',"mixture_{'mnist_test': 1, 'fashion': 99}_scod_flagged_99_train_1"), 
#             ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

for b in range(num_batches):
    initialized_model, exp_lr_scheduler, sgd_optimizer, criterion, device = set_up_model(dataset_name)
    load_model_path = "./best_model/mnist/best_model.pt"
    model, optimizer, start_epoch_idx, valid_loss = load_ckp(load_model_path, initialized_model, sgd_optimizer)
    print("start_epoch_idx = ", start_epoch_idx)
    print("valid_loss = {:.6f}".format(valid_loss))

    start_epochs = start_epoch_idx
    num_epochs = 15
    scheduler = exp_lr_scheduler

    # phases = [('train',"mixture_{'mnist_test': 1, 'fashion': 99}_scod_flagged_99_train_1_batch_"+str(b)), 
    #         ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

    # phases = [('train',"mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_100_batch_"+str(b)), 
    #         ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]
    
    # phases = [('train',"mixture_{'mnist_test': 90, 'kmnist': 10}_scod_flagged_10_train_100_batch_"+str(b)), 
    #         ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

    # phases = [('train',"mixture_{'mnist_test': 1, 'kmnist': 99}_scod_flagged_99_train_1_batch_"+str(b)), 
    #         ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

    phases = [('train',"mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_"+str(b)), 
            ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

    losses = {p[1]: np.zeros(num_epochs) for p in phases}

    # Resume training
    for epoch in range(start_epochs, start_epochs+num_epochs):
        print('Epoch {}/{}'.format(epoch+1, start_epochs+num_epochs))
        print('-' * 10)
        for phase in phases:
            if phase[0] == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()

            running_loss = 0.0

            # batch loop
            for d in dataloaders[phase[1]]:
                if len(d) == 2:
                    inputs, labels = d 
                elif len(d) == 3:
                    inputs, labels, fnames = d 
                else:
                    raise ValueError("Unrecognized. Dataloader entry has length {}".format(len(d)))
                labels = labels.flatten().type(torch.LongTensor)

                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase[0] == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    if phase[0] == 'train':
                        loss.backward()
                        optimizer.step()
                running_loss += loss.item() * inputs.size(0)
            epoch_loss = running_loss / dataset_sizes[phase[1]]
            print('{} {} Loss: {:.4f}'.format(phase[0], phase[1], epoch_loss))
            if phase[0] == 'train':
                scheduler.step()
            losses[phase[1]][epoch-start_epochs] = epoch_loss

    # Save train losses and valid losses
    losses_path = "./losses/"
    fname = "our_batch_"+str(b)+"_"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S") +'.npz' 
    with open(losses_path+fname, "wb") as fp:
        pickle.dump(losses, fp)
# Out:
# start_epoch_idx =  17
# valid_loss = 0.042841
# Epoch 18/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.4802
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9642
# val kmnist Loss: 8.5944
# Epoch 19/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.4583
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9337
# val kmnist Loss: 8.5621
# Epoch 20/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.4172
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8912
# val kmnist Loss: 8.5166
# Epoch 21/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.3595
# val mnist_test Loss: 0.0426
# val fashion Loss: 5.8386
# val kmnist Loss: 8.4596
# Epoch 22/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.2875
# val mnist_test Loss: 0.0426
# val fashion Loss: 5.7775
# val kmnist Loss: 8.3930
# Epoch 23/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.2035
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.7097
# val kmnist Loss: 8.3180
# Epoch 24/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.1090
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6366
# val kmnist Loss: 8.2361
# Epoch 25/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 6.0057
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6288
# val kmnist Loss: 8.2273
# Epoch 26/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9946
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6205
# val kmnist Loss: 8.2179
# Epoch 27/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9828
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6118
# val kmnist Loss: 8.2080
# Epoch 28/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9702
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6027
# val kmnist Loss: 8.1977
# Epoch 29/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9571
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5932
# val kmnist Loss: 8.1869
# Epoch 30/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9434
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5834
# val kmnist Loss: 8.1758
# Epoch 31/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9292
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5733
# val kmnist Loss: 8.1643
# Epoch 32/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_0 Loss: 5.9146
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5723
# val kmnist Loss: 8.1631
# start_epoch_idx =  17
# valid_loss = 0.042841
# Epoch 18/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.7476
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9631
# val kmnist Loss: 8.5922
# Epoch 19/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.7239
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9308
# val kmnist Loss: 8.5559
# Epoch 20/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.6794
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8861
# val kmnist Loss: 8.5048
# Epoch 21/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.6170
# val mnist_test Loss: 0.0426
# val fashion Loss: 5.8308
# val kmnist Loss: 8.4408
# Epoch 22/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.5389
# val mnist_test Loss: 0.0426
# val fashion Loss: 5.7670
# val kmnist Loss: 8.3660
# Epoch 23/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.4478
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6965
# val kmnist Loss: 8.2819
# Epoch 24/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.3460
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6208
# val kmnist Loss: 8.1903
# Epoch 25/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.2353
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6127
# val kmnist Loss: 8.1805
# Epoch 26/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.2234
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.6042
# val kmnist Loss: 8.1700
# Epoch 27/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.2108
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5952
# val kmnist Loss: 8.1590
# Epoch 28/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.1974
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5858
# val kmnist Loss: 8.1474
# Epoch 29/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.1835
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5761
# val kmnist Loss: 8.1354
# Epoch 30/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.1690
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5661
# val kmnist Loss: 8.1230
# Epoch 31/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.1540
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5559
# val kmnist Loss: 8.1103
# Epoch 32/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_1 Loss: 6.1386
# val mnist_test Loss: 0.0425
# val fashion Loss: 5.5548
# val kmnist Loss: 8.1090
# start_epoch_idx =  17
# valid_loss = 0.042841
# Epoch 18/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.5024
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9656
# val kmnist Loss: 8.5944
# Epoch 19/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.4806
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9379
# val kmnist Loss: 8.5622
# Epoch 20/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.4395
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.8991
# val kmnist Loss: 8.5167
# Epoch 21/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.3816
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8511
# val kmnist Loss: 8.4598
# Epoch 22/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.3091
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.7953
# val kmnist Loss: 8.3932
# Epoch 23/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.2242
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.7334
# val kmnist Loss: 8.3185
# Epoch 24/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.1287
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6665
# val kmnist Loss: 8.2368
# Epoch 25/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.0239
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6594
# val kmnist Loss: 8.2280
# Epoch 26/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.0127
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6518
# val kmnist Loss: 8.2187
# Epoch 27/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 6.0006
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6438
# val kmnist Loss: 8.2088
# Epoch 28/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 5.9879
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6355
# val kmnist Loss: 8.1985
# Epoch 29/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 5.9746
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6268
# val kmnist Loss: 8.1877
# Epoch 30/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 5.9607
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6179
# val kmnist Loss: 8.1766
# Epoch 31/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 5.9464
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6088
# val kmnist Loss: 8.1652
# Epoch 32/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_2 Loss: 5.9316
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6078
# val kmnist Loss: 8.1640
# start_epoch_idx =  17
# valid_loss = 0.042841
# Epoch 18/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 8.2179
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9515
# val kmnist Loss: 8.5850
# Epoch 19/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 8.1723
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.8980
# val kmnist Loss: 8.5353
# Epoch 20/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 8.0877
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.8240
# val kmnist Loss: 8.4663
# Epoch 21/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.9703
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.7338
# val kmnist Loss: 8.3814
# Epoch 22/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.8265
# val mnist_test Loss: 0.0431
# val fashion Loss: 5.6316
# val kmnist Loss: 8.2841
# Epoch 23/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.6624
# val mnist_test Loss: 0.0435
# val fashion Loss: 5.5209
# val kmnist Loss: 8.1773
# Epoch 24/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.4845
# val mnist_test Loss: 0.0441
# val fashion Loss: 5.4052
# val kmnist Loss: 8.0637
# Epoch 25/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.2976
# val mnist_test Loss: 0.0442
# val fashion Loss: 5.3931
# val kmnist Loss: 8.0517
# Epoch 26/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.2779
# val mnist_test Loss: 0.0442
# val fashion Loss: 5.3804
# val kmnist Loss: 8.0390
# Epoch 27/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.2571
# val mnist_test Loss: 0.0443
# val fashion Loss: 5.3671
# val kmnist Loss: 8.0257
# Epoch 28/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.2354
# val mnist_test Loss: 0.0444
# val fashion Loss: 5.3534
# val kmnist Loss: 8.0119
# Epoch 29/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.2128
# val mnist_test Loss: 0.0445
# val fashion Loss: 5.3392
# val kmnist Loss: 7.9976
# Epoch 30/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.1896
# val mnist_test Loss: 0.0446
# val fashion Loss: 5.3247
# val kmnist Loss: 7.9829
# Epoch 31/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.1657
# val mnist_test Loss: 0.0447
# val fashion Loss: 5.3099
# val kmnist Loss: 7.9679
# Epoch 32/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_3 Loss: 7.1414
# val mnist_test Loss: 0.0447
# val fashion Loss: 5.3084
# val kmnist Loss: 7.9663
# start_epoch_idx =  17
# valid_loss = 0.042841
# Epoch 18/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.8313
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9673
# val kmnist Loss: 8.5962
# Epoch 19/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.8100
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.9428
# val kmnist Loss: 8.5672
# Epoch 20/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.7701
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.9085
# val kmnist Loss: 8.5265
# Epoch 21/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.7140
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8660
# val kmnist Loss: 8.4758
# Epoch 22/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.6442
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8166
# val kmnist Loss: 8.4165
# Epoch 23/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.5625
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.7615
# val kmnist Loss: 8.3500
# Epoch 24/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.4709
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.7020
# val kmnist Loss: 8.2777
# Epoch 25/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3713
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6956
# val kmnist Loss: 8.2700
# Epoch 26/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3607
# val mnist_test Loss: 0.0428
# val fashion Loss: 5.6889
# val kmnist Loss: 8.2618
# Epoch 27/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3494
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6817
# val kmnist Loss: 8.2531
# Epoch 28/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3375
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6743
# val kmnist Loss: 8.2441
# Epoch 29/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3250
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6666
# val kmnist Loss: 8.2347
# Epoch 30/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.3120
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6587
# val kmnist Loss: 8.2250
# Epoch 31/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.2985
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6506
# val kmnist Loss: 8.2151
# Epoch 32/32
# ----------
# train mixture_{'mnist_test': 50, 'kmnist': 50}_scod_flagged_50_train_1_batch_4 Loss: 5.2847
# val mnist_test Loss: 0.0429
# val fashion Loss: 5.6498
# val kmnist Loss: 8.2140

# %% [markdown]
# # Resume training with EWC-inspired regularization

# %%
initialized_model, exp_lr_scheduler, sgd_optimizer, criterion, device = set_up_model(dataset_name)
load_model_path = "./best_model/mnist/best_model.pt"
model, optimizer, start_epoch_idx, valid_loss = load_ckp(load_model_path, initialized_model, sgd_optimizer)
print("start_epoch_idx = ", start_epoch_idx)
print("valid_loss = {:.6f}".format(valid_loss))
# Out:
# start_epoch_idx =  17
# valid_loss = 0.042841

# %%
start_epochs = start_epoch_idx
num_epochs = 1
scheduler = exp_lr_scheduler

# Resume training on train set
# phases = [('train','mnist_train'), ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

# Resume training on mixture
phases = [('train',"mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_100"), 
            ('val','mnist_test'), ('val','fashion'), ('val','kmnist')]

losses = {p[1]: np.zeros(num_epochs) for p in phases}

dist_layer = scod.distributions.CategoricalLogitLayer()

# Resume training
for epoch in range(start_epochs, start_epochs+num_epochs):
    print('Epoch {}/{}'.format(epoch+1, start_epochs+num_epochs))
    print('-' * 10)

    # Create new unc model
    new_unc_model = init_scod(model, dataloaders["mnist_train"], dataset_name) 

    for phase in phases:
        if phase[0] == 'train':
            model.train()  # Set model to training mode
        else:
            model.eval()

        running_loss = 0.0

        # batch loop
        for d in dataloaders[phase[1]]:
            if len(d) == 2:
                inputs, labels = d 
            elif len(d) == 3:
                inputs, labels, fnames = d 
            else:
                raise ValueError("Unrecognized. Dataloader entry has length {}".format(len(d)))
            labels = labels.flatten().type(torch.LongTensor)

            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase[0] == 'train'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                

                if phase[0] == 'train':
                    for i in inputs[:2]:
                        unc = eval_scod(i, unc_model, dist_layer)
                        unc = unc.item()
                        print("Uncertainty: ", unc)
                        LtJ = get_Lt_J(i.unsqueeze(0), unc_model, debug=False, dist_layer=dist_layer)
                        orig_trace = np.trace(LtJ)
                        print("LtJ shape is ", np.shape(LtJ))

                        new_unc = eval_scod(i, new_unc_model, dist_layer)
                        new_unc = new_unc.item()
                        print("New Uncertainty: ", new_unc)
                        new_LtJ = get_Lt_J(i.unsqueeze(0), new_unc_model, debug=False, dist_layer=dist_layer)
                        diff = np.trace(new_LtJ - LtJ)
                        print("Trace is ", diff/orig_trace)


                    loss.backward()
                    optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        epoch_loss = running_loss / dataset_sizes[phase[1]]
        print('{} {} Loss: {:.4f}'.format(phase[0], phase[1], epoch_loss))
        if phase[0] == 'train':
            scheduler.step()
        losses[phase[1]][epoch-start_epochs] = epoch_loss

print(losses)
# Out:
# Epoch 18/18
# ----------
# Weight space dimension: 4.443e+04
# computing basis
# using T = 304
#   0%|          | 0/480 [00:00<?, ?it/s]
# Uncertainty:  2.294168472290039
# LtJ shape is  (10, 44426)
# New Uncertainty:  2.294233798980713
# Trace is  0.0057763914
# Uncertainty:  2.2781007289886475
# LtJ shape is  (10, 44426)
# New Uncertainty:  2.2781505584716797
# Trace is  0.039836433
# Uncertainty:  2.2669413089752197
# LtJ shape is  (10, 44426)
# New Uncertainty:  2.266752243041992
# Trace is  -0.010459036
# Uncertainty:  2.258082151412964
# LtJ shape is  (10, 44426)
# New Uncertainty:  2.2576828002929688
# Trace is  0.052654635
# train mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_100 Loss: 0.3520
# val mnist_test Loss: 0.0427
# val fashion Loss: 5.8917
# val kmnist Loss: 8.5776
# {"mixture_{'mnist_test': 90, 'fashion': 10}_scod_flagged_10_train_100": array([0.35199595]), 'mnist_test': array([0.04272059]), 'fashion': array([5.89165637]), 'kmnist': array([8.57758451])}

# %% [markdown]
# # [Unused] Create mixture dataset using flagged inputs and weighting by uncertainty

# %%
ood_ratio = 0.1
mix_train_ratio = 1.0
num_batches = 1

ood_num = int(batch_size*ood_ratio)
mix_train_num = int(batch_size*mix_train_ratio)

batch_compositions = [  {'mnist_test':batch_size - ood_num,'fashion':ood_num}]
train_batch_compositions = [{'mnist_train':mix_train_num}]

flag_limit = ood_num
# algs_to_test = [lambda x: scod_flagger(x, unc_model, flag_limit=flag_limit, debug = False, dist_layer = scod.distributions.CategoricalLogitLayer()), 
#                 lambda x: ds_scod_flagger(x, unc_model, flag_limit=flag_limit, dist_layer = scod.distributions.CategoricalLogitLayer())]
algs_to_test = [lambda x: scod_flagger(x, unc_model, flag_limit=flag_limit, debug = False, dist_layer = scod.distributions.CategoricalLogitLayer())] 
algs_names = ['scod_flagged']

flagged_inputs, flagged_labels, flagged_fnames, flags = alg_flags(algs_to_test, dataset_name, batch_size, num_batches, batch_compositions)
train_inputs, train_labels, train_fnames = create_benchmark_seq_batches(dataset_name, mix_train_num, num_batches, train_batch_compositions)
for k in range(len(algs_to_test)):
    for i in range(num_batches):
        flagged_subset = [(ts, lbl) for (ts,lbl,flg) in zip(flagged_inputs[i], flagged_labels[i], flags[i][k]) if flg]
        train_subset = [(ts, lbl) for (ts,lbl) in zip(train_inputs[i], train_labels[i])]
        
        if unc_model is not None:
            dist_layer = scod.distributions.CategoricalLogitLayer()
            for fs in flagged_subset:
                unc = eval_scod(fs[0] , unc_model, dist_layer)
                unc = unc.item()
                print("Uncertainty: ", unc)
        
        # refine_subset = flagged_subset + train_subset
        # random.shuffle(refine_subset)

        # mix_name = "mixture_weighted"+str(batch_compositions[i])+'_'+algs_names[k]+'_'+str(len(flagged_subset))+'_train_'+str(len(train_subset))
        
        # dataloaders[mix_name] = DataLoader(refine_subset, batch_size=batch_size, shuffle=True, num_workers=8)
        # dataset_sizes[mix_name]  = len(refine_subset)
        # print("Added ", mix_name, " to list of dataloaders.")
# Out:
# Test seq  0  algorithm  0  flagged:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, True, False, True, True, True]
# Uncertainty:  2.293386936187744
# Uncertainty:  2.296449899673462
# Uncertainty:  2.2916970252990723
# Uncertainty:  2.295175552368164
# Uncertainty:  2.2911081314086914
# Uncertainty:  2.2927355766296387
# Uncertainty:  2.294149398803711
# Uncertainty:  2.2983007431030273
# Uncertainty:  2.2959296703338623
# Uncertainty:  2.299753189086914
